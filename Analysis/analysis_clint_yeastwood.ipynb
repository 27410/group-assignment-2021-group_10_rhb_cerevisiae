# %%
import csv
from cobra.io import read_sbml_model, write_sbml_model
from copy import copy
from dotenv import find_dotenv
import os
from os.path import dirname

# %%
MODEL_PATH = "models/MODEL1709260000_url.xml"

# %%
model = read_sbml_model(MODEL_PATH) # loading
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0001 "(1->3)-beta-D-glucan [cell envelope]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0001 "(1->3)-beta-D-glucan [cell envelope]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0002 "(1->3)-beta-D-glucan [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0002 "(1->3)-beta-D-glucan [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0003 "(1->3)-beta-D-glucan [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0003 "(1->3)-beta-D-glucan [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0004 "(1->6)-beta-D-glucan [cell envelope]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0004 "(1->6)-beta-D-glucan [cell envelope]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0006 "(2-amino-4-hydroxy-7,8-dihydropteridin-6-yl)methyl trihydrogen diphosphate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0006 "(2-amino-4-hydroxy-7,8-dihydropteridin-6-yl)methyl trihydrogen diphosphate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0007 "(2E)-3-(methoxycarbonyl)pent-2-enedioic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0007 "(2E)-3-(methoxycarbonyl)pent-2-enedioic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0008 "(2R,3R)-2,3-dihydroxy-3-methylpentanoate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0008 "(2R,3R)-2,3-dihydroxy-3-methylpentanoate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0009 "(2R,3S)-3-isopropylmalate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0009 "(2R,3S)-3-isopropylmalate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0010 "(2S)-2-isopropyl-3-oxosuccinate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0010 "(2S)-2-isopropyl-3-oxosuccinate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0011 "(2S)-2-isopropyl-3-oxosuccinate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0011 "(2S)-2-isopropyl-3-oxosuccinate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0012 "(2S,3R)-3-hydroxybutane-1,2,3-tricarboxylic acid [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0012 "(2S,3R)-3-hydroxybutane-1,2,3-tricarboxylic acid [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0013 "(5S,6S)-di-HETE [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0013 "(5S,6S)-di-HETE [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0014 "(5S,6S)-di-HETE [nucleus]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0014 "(5S,6S)-di-HETE [nucleus]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0015 "(N(omega)-L-arginino)succinic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0015 "(N(omega)-L-arginino)succinic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0016 "(R)-2,3-dihydroxy-3-methylbutanoate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0016 "(R)-2,3-dihydroxy-3-methylbutanoate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0017 "(R)-4'-phosphopantothenic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0017 "(R)-4'-phosphopantothenic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0018 "(R)-5-diphosphomevalonic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0018 "(R)-5-diphosphomevalonic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0019 "(R)-5-phosphomevalonic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0019 "(R)-5-phosphomevalonic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0020 "(R)-acetoin [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0020 "(R)-acetoin [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0021 "(R)-carnitine [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0021 "(R)-carnitine [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0022 "(R)-carnitine [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0022 "(R)-carnitine [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0023 "(R)-carnitine [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0023 "(R)-carnitine [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0024 "(R)-carnitine [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0024 "(R)-carnitine [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0025 "(R)-lactate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0025 "(R)-lactate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0026 "(R)-lactate [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0026 "(R)-lactate [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0027 "(R)-lactate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0027 "(R)-lactate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0028 "(R)-mevalonate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0028 "(R)-mevalonate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0029 "(R)-mevalonate [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0029 "(R)-mevalonate [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0030 "(R)-pantoate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0030 "(R)-pantoate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0031 "(R)-pantothenate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0031 "(R)-pantothenate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0032 "(R)-pantothenate [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0032 "(R)-pantothenate [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0033 "(R)-S-lactoylglutathione [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0033 "(R)-S-lactoylglutathione [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0034 "(R)-S-lactoylglutathione [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0034 "(R)-S-lactoylglutathione [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0035 "(R,R)-2,3-butanediol [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0035 "(R,R)-2,3-butanediol [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0036 "(R,R)-2,3-butanediol [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0036 "(R,R)-2,3-butanediol [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0037 "(S)-2,3-epoxysqualene [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0037 "(S)-2,3-epoxysqualene [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0038 "(S)-2,3-epoxysqualene [endoplasmic reticulum]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0038 "(S)-2,3-epoxysqualene [endoplasmic reticulum]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0039 "(S)-2-acetyl-2-hydroxybutanoate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0039 "(S)-2-acetyl-2-hydroxybutanoate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0042 "(R)-3-hydroxydecanoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0042 "(R)-3-hydroxydecanoyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0045 "(S)-3-hydroxyhexacosanoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0045 "(S)-3-hydroxyhexacosanoyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0048 "(R)-3-hydroxylauroyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0048 "(R)-3-hydroxylauroyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0051 "(S)-3-hydroxypalmitoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0051 "(S)-3-hydroxypalmitoyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0054 "(S)-3-hydroxytetradecanoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0054 "(S)-3-hydroxytetradecanoyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0056 "(S)-3-methyl-2-oxopentanoate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0056 "(S)-3-methyl-2-oxopentanoate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0058 "(S)-3-methyl-2-oxopentanoate [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0058 "(S)-3-methyl-2-oxopentanoate [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0060 "(S)-3-methyl-2-oxopentanoate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0060 "(S)-3-methyl-2-oxopentanoate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0061 "(S)-dihydroorotate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0061 "(S)-dihydroorotate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0062 "(S)-lactaldehyde [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0062 "(S)-lactaldehyde [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0063 "(S)-lactate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0063 "(S)-lactate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0064 "(S)-lactate [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0064 "(S)-lactate [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0065 "(S)-lactate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0065 "(S)-lactate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0066 "(S)-malate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0066 "(S)-malate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0067 "(S)-malate [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0067 "(S)-malate [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0068 "(S)-malate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0068 "(S)-malate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0069 "(S)-malate [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0069 "(S)-malate [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0075 "1,3-bisphospho-D-glycerate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0075 "1,3-bisphospho-D-glycerate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0076 "1-(2-carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0076 "1-(2-carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0077 "1-(5-phospho-D-ribosyl)-5-[(5-phospho-D-ribosylamino)methylideneamino]imidazole-4-carboxamide [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0077 "1-(5-phospho-D-ribosyl)-5-[(5-phospho-D-ribosylamino)methylideneamino]imidazole-4-carboxamide [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0078 "1-(5-phosphoribosyl)-5'-AMP [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0078 "1-(5-phosphoribosyl)-5'-AMP [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0079 "1-(sn-glycero-3-phospho)-1D-myo-inositol [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0079 "1-(sn-glycero-3-phospho)-1D-myo-inositol [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0080 "1-(sn-glycero-3-phospho)-1D-myo-inositol [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0080 "1-(sn-glycero-3-phospho)-1D-myo-inositol [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0084 "1-acylglycerophosphocholine [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0084 "1-acylglycerophosphocholine [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0086 "1-C-(indol-3-yl)glycerol 3-phosphate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0086 "1-C-(indol-3-yl)glycerol 3-phosphate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0087 "1-methylnicotinamide [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0087 "1-methylnicotinamide [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0089 "1-phosphatidyl-1D-myo-inositol [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0089 "1-phosphatidyl-1D-myo-inositol [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0116 "1-pyrroline-3-hydroxy-5-carboxylic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0116 "1-pyrroline-3-hydroxy-5-carboxylic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0117 "1-pyrroline-3-hydroxy-5-carboxylic acid [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0117 "1-pyrroline-3-hydroxy-5-carboxylic acid [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0118 "1-pyrroline-5-carboxylate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0118 "1-pyrroline-5-carboxylate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0119 "1-pyrroline-5-carboxylate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0119 "1-pyrroline-5-carboxylate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0120 "10-formyl-THF [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0120 "10-formyl-THF [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0121 "10-formyl-THF [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0121 "10-formyl-THF [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0122 "14-demethyllanosterol [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0122 "14-demethyllanosterol [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0123 "1D-myo-inositol 1,3,4,5-tetrakisphosphate [nucleus]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0123 "1D-myo-inositol 1,3,4,5-tetrakisphosphate [nucleus]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0124 "1D-myo-inositol 1,4,5,6-tetrakisphosphate [nucleus]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0124 "1D-myo-inositol 1,4,5,6-tetrakisphosphate [nucleus]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0125 "1D-myo-inositol 1,4,5-trisphosphate [nucleus]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0125 "1D-myo-inositol 1,4,5-trisphosphate [nucleus]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0126 "1D-myo-inositol 1-phosphate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0126 "1D-myo-inositol 1-phosphate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0127 "1D-myo-inositol 1-phosphate [endoplasmic reticulum]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0127 "1D-myo-inositol 1-phosphate [endoplasmic reticulum]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0129 "1D-myo-inositol 3-phosphate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0129 "1D-myo-inositol 3-phosphate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0131 "2',3'-cyclic AMP [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0131 "2',3'-cyclic AMP [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0132 "2'-deoxyadenosine [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0132 "2'-deoxyadenosine [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0133 "2'-deoxyadenosine [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0133 "2'-deoxyadenosine [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0134 "2'-deoxyguanosine [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0134 "2'-deoxyguanosine [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0135 "2'-deoxyguanosine [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0135 "2'-deoxyguanosine [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0136 "2'-deoxyinosine [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0136 "2'-deoxyinosine [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0137 "2'-deoxyinosine [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0137 "2'-deoxyinosine [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0138 "2'-deoxyuridine [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0138 "2'-deoxyuridine [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0139 "2'-deoxyuridine [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0139 "2'-deoxyuridine [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0140 "2,3-bisphospho-D-glyceric acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0140 "2,3-bisphospho-D-glyceric acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0141 "2,5-diamino-4-hydroxy-6-(5-phosphoribosylamino)pyrimidine [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0141 "2,5-diamino-4-hydroxy-6-(5-phosphoribosylamino)pyrimidine [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0142 "2,5-diamino-6-(5-phosphono)ribitylamino-4(3H)-pyrimidinone [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0142 "2,5-diamino-6-(5-phosphono)ribitylamino-4(3H)-pyrimidinone [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0143 "2-(3-amino-3-carboxypropyl)-L-histidine [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0143 "2-(3-amino-3-carboxypropyl)-L-histidine [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0144 "2-[3-carboxy-3-(methylammonio)propyl]-L-histidine [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0144 "2-[3-carboxy-3-(methylammonio)propyl]-L-histidine [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0145 "2-acetamido-5-oxopentanoate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0145 "2-acetamido-5-oxopentanoate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0146 "2-acetyllactic acid [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0146 "2-acetyllactic acid [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0147 "2-amino-3-carboxymuconate-6-semialdehyde [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0147 "2-amino-3-carboxymuconate-6-semialdehyde [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0148 "2-amino-6-(hydroxymethyl)-7,8-dihydropteridin-4-ol [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0148 "2-amino-6-(hydroxymethyl)-7,8-dihydropteridin-4-ol [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0149 "2-dehydropantoate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0149 "2-dehydropantoate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0150 "2-dehydropantoate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0150 "2-dehydropantoate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0152 "2-deoxy-D-ribose [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0152 "2-deoxy-D-ribose [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0153 "2-deoxy-D-ribose 5-phosphate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0153 "2-deoxy-D-ribose 5-phosphate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0154 "2-hexaprenyl-5-hydroxy-6-methoxy-3-methyl-1,4-benzoquinone [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0154 "2-hexaprenyl-5-hydroxy-6-methoxy-3-methyl-1,4-benzoquinone [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0155 "2-hexaprenyl-6-methoxy-1,4-benzoquinone [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0155 "2-hexaprenyl-6-methoxy-1,4-benzoquinone [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0156 "2-hexaprenyl-6-methoxy-3-methyl-1,4-benzoquinone [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0156 "2-hexaprenyl-6-methoxy-3-methyl-1,4-benzoquinone [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0157 "2-hexaprenyl-6-methoxyphenol [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0157 "2-hexaprenyl-6-methoxyphenol [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0158 "2-hydroxy-3-oxobutyl phosphate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0158 "2-hydroxy-3-oxobutyl phosphate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0161 "2-hydroxyhexadecanal [endoplasmic reticulum]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0161 "2-hydroxyhexadecanal [endoplasmic reticulum]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0162 "2-isopropylmalate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0162 "2-isopropylmalate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0163 "2-isopropylmalate [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0163 "2-isopropylmalate [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0164 "2-isopropylmalate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0164 "2-isopropylmalate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0165 "2-isopropylmaleic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0165 "2-isopropylmaleic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0166 "2-methylbutanal [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0166 "2-methylbutanal [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0167 "2-methylbutanal [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0167 "2-methylbutanal [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0168 "2-methylbutanal [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0168 "2-methylbutanal [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0169 "2-methylbutanol [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0169 "2-methylbutanol [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0170 "2-methylbutanol [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0170 "2-methylbutanol [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0171 "2-methylbutanol [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0171 "2-methylbutanol [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0172 "2-methylbutyl acetate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0172 "2-methylbutyl acetate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0173 "2-methylbutyl acetate [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0173 "2-methylbutyl acetate [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0174 "2-methylcitrate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0174 "2-methylcitrate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0176 "2-oxoadipic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0176 "2-oxoadipic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0177 "2-oxoadipic acid [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0177 "2-oxoadipic acid [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0178 "2-oxobutanoate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0178 "2-oxobutanoate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0179 "2-oxobutanoate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0179 "2-oxobutanoate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0180 "2-oxoglutarate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0180 "2-oxoglutarate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0181 "2-oxoglutarate [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0181 "2-oxoglutarate [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0182 "2-oxoglutarate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0182 "2-oxoglutarate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0183 "2-oxoglutarate [nucleus]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0183 "2-oxoglutarate [nucleus]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0184 "2-oxoglutarate [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0184 "2-oxoglutarate [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0185 "2-phenylethanol [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0185 "2-phenylethanol [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0186 "2-phenylethanol [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0186 "2-phenylethanol [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0187 "2-phenylethanol [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0187 "2-phenylethanol [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0188 "2-phospho-D-glyceric acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0188 "2-phospho-D-glyceric acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0189 "geranylgeranyl diphosphate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0189 "geranylgeranyl diphosphate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0190 "farnesyl diphosphate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0190 "farnesyl diphosphate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0191 "farnesyl diphosphate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0191 "farnesyl diphosphate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0192 "3',5'-cyclic AMP [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0192 "3',5'-cyclic AMP [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0193 "3',5'-cyclic CMP [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0193 "3',5'-cyclic CMP [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0194 "3',5'-cyclic dAMP [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0194 "3',5'-cyclic dAMP [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0195 "3',5'-cyclic GMP [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0195 "3',5'-cyclic GMP [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0196 "3',5'-cyclic IMP [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0196 "3',5'-cyclic IMP [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0197 "3'-dephospho-CoA [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0197 "3'-dephospho-CoA [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0200 "3'-dephospho-CoA [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0200 "3'-dephospho-CoA [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0201 "3'-phospho-5'-adenylyl sulfate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0201 "3'-phospho-5'-adenylyl sulfate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0204 "3-(4-hydroxyphenyl)pyruvate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0204 "3-(4-hydroxyphenyl)pyruvate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0206 "3-(4-hydroxyphenyl)pyruvate [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0206 "3-(4-hydroxyphenyl)pyruvate [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0207 "3-(imidazol-4-yl)-2-oxopropyl dihydrogen phosphate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0207 "3-(imidazol-4-yl)-2-oxopropyl dihydrogen phosphate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0208 "3-aminopropanal [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0208 "3-aminopropanal [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0209 "3-dehydro-4-methylzymosterol [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0209 "3-dehydro-4-methylzymosterol [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0210 "3-dehydroquinate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0210 "3-dehydroquinate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0211 "3-dehydroshikimate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0211 "3-dehydroshikimate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0212 "3-hexaprenyl-4,5-dihydroxybenzoic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0212 "3-hexaprenyl-4,5-dihydroxybenzoic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0213 "3-hexaprenyl-4,5-dihydroxybenzoic acid [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0213 "3-hexaprenyl-4,5-dihydroxybenzoic acid [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0214 "3-hexaprenyl-4-hydroxy-5-methoxybenzoic acid [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0214 "3-hexaprenyl-4-hydroxy-5-methoxybenzoic acid [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0215 "3-hexaprenyl-4-hydroxybenzoic acid [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0215 "3-hexaprenyl-4-hydroxybenzoic acid [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0216 "3-hexaprenyl-4-hydroxybenzoic acid [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0216 "3-hexaprenyl-4-hydroxybenzoic acid [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0217 "3-hydroxy-2-isopropyl-4-methoxy-4-oxobutanoate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0217 "3-hydroxy-2-isopropyl-4-methoxy-4-oxobutanoate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0218 "3-hydroxy-3-methylglutaryl-CoA [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0218 "3-hydroxy-3-methylglutaryl-CoA [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0221 "3-hydroxy-3-methylglutaryl-CoA [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0221 "3-hydroxy-3-methylglutaryl-CoA [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0222 "3-hydroxy-L-kynurenine [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0222 "3-hydroxy-L-kynurenine [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0224 "3-hydroxyanthranilate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0224 "3-hydroxyanthranilate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0229 "3-hydroxyoctadecanoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0229 "3-hydroxyoctadecanoyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0231 "3-ketosphinganine [endoplasmic reticulum]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0231 "3-ketosphinganine [endoplasmic reticulum]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0232 "3-methyl-2-oxobutanoate [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0232 "3-methyl-2-oxobutanoate [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0233 "3-methyl-2-oxobutanoate [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0233 "3-methyl-2-oxobutanoate [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0234 "3-methylbutanal [cytoplasm]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0234 "3-methylbutanal [cytoplasm]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0235 "3-methylbutanal [extracellular]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0235 "3-methylbutanal [extracellular]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0236 "3-methylbutanal [mitochondrion]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0236 "3-methylbutanal [mitochondrion]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0239 "3-oxodecanoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0239 "3-oxodecanoyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0243 "3-oxohexacosanoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0243 "3-oxohexacosanoyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0247 "3-oxolauroyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0247 "3-oxolauroyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0250 "3-oxooctadecanoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0250 "3-oxooctadecanoyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0253 "3-oxopalmitoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0253 "3-oxopalmitoyl-CoA [peroxisome]">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species s_0257 "3-oxotetradecanoyl-CoA [peroxisome]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species s_0257 "3-oxotetradecanoyl-CoA [peroxisome]">
# ...
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0610 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0611 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0611 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0612 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0612 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0613 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0613 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0614 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0614 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0615 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0615 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0616 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0616 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0617 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0617 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0618 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0618 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0619 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0619 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0620 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0620 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0621 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0621 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0622 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0622 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0623 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0623 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0624 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0624 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0625 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0625 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0626 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0626 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0627 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0627 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0628 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0628 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0629 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0629 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0630 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0630 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0631 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0631 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0632 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0632 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0633 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0633 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0634 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0634 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0635 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0635 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0636 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0636 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0637 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0637 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0638 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0638 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0639 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0639 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0640 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0640 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0641 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0641 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0642 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0642 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0643 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0643 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0644 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0644 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0645 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0645 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0646 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0646 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0647 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0647 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0648 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0648 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0649 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0649 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0650 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0650 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0651 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0651 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0652 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0652 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0653 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0653 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0654 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0654 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0655 "IPS phospholipase C">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0655 "IPS phospholipase C">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0656 "isoamyl acetate-hydrolyzing esterase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0656 "isoamyl acetate-hydrolyzing esterase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0657 "isobutyl acetate-hydrolyzing esterase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0657 "isobutyl acetate-hydrolyzing esterase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0658 "isocitrate dehydrogenase (NAD+)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0658 "isocitrate dehydrogenase (NAD+)">
# Removing parenthesis from gpr (YNL037C AND YOR136W) leads to an error, so keeping parenthesis
# C:\Users\andre\anaconda3\envs\gem\lib\site-packages\cobra\core\reaction.py:432: UserWarning: uppercase AND/OR found in rule '(YNL037C AND YOR136W)' for '<Reaction r_0658 at 0x2b4aeae4288>'
#   % (new_rule, repr(self))
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0659 "isocitrate dehydrogenase (NADP)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0659 "isocitrate dehydrogenase (NADP)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0661 "isocitrate dehydrogenase (NADP+), peroxisomal">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0661 "isocitrate dehydrogenase (NADP+), peroxisomal">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0662 "isocitrate lyase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0662 "isocitrate lyase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0663 "isoleucine transaminase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0663 "isoleucine transaminase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0664 "isoleucine transaminase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0664 "isoleucine transaminase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0665 "isoleucyl-tRNA synthetase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0665 "isoleucyl-tRNA synthetase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0666 "isoleucyl-tRNA synthetase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0666 "isoleucyl-tRNA synthetase">

# %% [markdown]
# We write the model to a new xml file so that we avoid the warnings in the future.

# %%
write_sbml_model(model,"model_clint_yeastwood.xml")   # saving

# %%
print("The model contains "+str(len(model.genes))+" genes, "+str(len(model.metabolites))+" metabolites and "+str(len(model.reactions))+" reactions.")
# Out:
# The model contains 1226 genes, 3543 metabolites and 4822 reactions.

# %% [markdown]
# # The model at a glance

# %%
for metabolite in model.metabolites.query('heme', 'name'):
    print(metabolite.name, metabolite.id)
# Out:
# ferroheme b [mitochondrion] s_0712
# heme a [mitochondrion] s_0811
# heme o [mitochondrion] s_0812
# siroheme [cytoplasm] s_1430
# heme a [cell envelope] s_1644
# heme a [vacuole] s_1647
# ferroheme b [cytoplasm] s_1650
# ferroheme b [endoplasmic reticulum] s_1651
# heme a [endoplasmic reticulum] s_1902
# heme a [peroxisome] s_1904
# hemeC [mitochondrion] s_1913
# hemeC1 [mitochondrion] s_1914
# heme a [cytoplasm] s_3714

# %%
for reaction in model.metabolites.s_0712.reactions:
    print(reaction.id, reaction)
# Out:
# r_0531 r_0531: s_0191 + s_0712 + s_0807 --> s_0636 + s_0812
# r_1400 r_1400: s_0712 --> s_1913
# r_1401 r_1401: s_0712 --> s_1914
# r_0436 r_0436: s_0926 + s_1383 --> s_0712 + 2.0 s_0799
# r_1307 r_1307: s_0712 <=> s_1650

# %%
r1 = model.reactions.get_by_id('r_3143')

# %%
r1.check_mass_balance()
# Out:
# {'charge': -2.0, 'H': -1.0, 'O': 3.0, 'P': 1.0}

# %%
r2 = model.reactions.get_by_id('r_3143')

# %%
r2.check_mass_balance()
# Out:
# {'charge': -2.0, 'H': -1.0, 'O': 3.0, 'P': 1.0}

# %%
model.optimize()
# Out:
# <Solution 0.088 at 0x2b4af2a6148>

# %%
model.compartments
# Out:
# {'c_02': 'cell envelope',
#  'c_03': 'cytoplasm',
#  'c_06': 'extracellular',
#  'c_11': 'mitochondrion',
#  'c_13': 'nucleus',
#  'c_15': 'peroxisome',
#  'c_04': 'endoplasmic reticulum',
#  'c_07': 'Golgi',
#  'c_09': 'lipid particle',
#  'c_17': 'vacuole',
#  'c_01': 'boundary',
#  'c_10': 'mitochondrial membrane',
#  'c_05': 'endoplasmic reticulum membrane',
#  'c_08': 'Golgi membrane',
#  'c_16': 'vacuolar membrane',
#  'c_14': 'peroxisomal membrane'}

# %% [markdown]
# We see that our model, being a eukaryote, contains more than a few compartments. Heme is synthesised around the mitochondria - with some reactions taking place in the mitochondria and other reactions takning place in the cytosol.
